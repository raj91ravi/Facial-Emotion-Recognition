# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ravi raj\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\ravi raj\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\ravi raj\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\ravi raj\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ravi raj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ravi raj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ravi raj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ravi raj\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ravi raj\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras as k
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,BatchNormalization,Activation,GlobalAveragePooling2D,Dropout,Dense,MaxPooling2D
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
# Load dataset directories
train = 'rafdb/DATASET/train'
test = 'rafdb/DATASET/test'

# %%
img_size=(48,48)
bth_size=32

# Augmenting Images for training set

trdatagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    validation_split=0.1
)

# Normalization of the pixel values for test Set
tedatagen = ImageDataGenerator(rescale=1.0/255)

# %%
# Reading the training data from directory

traingen= trdatagen.flow_from_directory(
    train,
    target_size=img_size,
    batch_size=bth_size,
    color_mode='grayscale',  
    class_mode='categorical',
    shuffle=True,
    subset='training')

# Reading the testing data from directory

testgen = tedatagen.flow_from_directory(
    test,
    target_size=img_size,
    batch_size=bth_size,
    color_mode='grayscale', 
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 11046 images belonging to 7 classes.
# Found 3068 images belonging to 7 classes.

# %%
# Displaying the training and testing datsets (only 5 images from each dataset)

def plot_images_from_generator(generator, title, num_images=5, images_per_row=5):
    images, labels = next(generator)
    images = images[:num_images]
    labels = labels[:num_images]
    num_rows = (num_images + images_per_row - 1) // images_per_row
    fig, axes = plt.subplots(num_rows, images_per_row, figsize=(15, 3 * num_rows))
    fig.suptitle(title, fontsize=16)
    axes = axes.flatten()
    for i in range(num_images):
        img = images[i]
        label = labels[i]
        axes[i].imshow(img)
        axes[i].axis('off')
        axes[i].set_title(f"Label: {list(generator.class_indices.keys())[label.argmax()]}")
    
    for j in range(num_images, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

plot_images_from_generator(traingen, "Training Set", num_images=10, images_per_row=5)
plot_images_from_generator(testgen, "Testing Set", num_images=10, images_per_row=5)

# %%
#class distribution

def plot_class_distribution(directory, title):
    class_names = os.listdir(directory)
    class_counts = []
    for class_name in class_names:
        class_dir = os.path.join(directory, class_name)
        if os.path.isdir(class_dir):
            class_counts.append(len(os.listdir(class_dir)))

    plt.figure(figsize=(10, 6))
    plt.bar(class_names, class_counts)
    plt.title(title)
    plt.xlabel('Emotion')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    plt.show()

plot_class_distribution(train, "Training Set Emotion Distribution")
plot_class_distribution(test, "Testing Set Emotion Distribution")

# %%
# Label Map
label_map = {
    0:'Angry', 
    1:'Disgust',
    2:'Fear',
    3:'Happy', 
    4:'Sad', 
    5:'Surprise', 
    6:'Neutral'
}

# %%
# Defining CNN model
model = Sequential()

# CNN Layer 1
model.add(Conv2D(64, (3,3), padding='same', input_shape=(48, 48, 1)))  
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# CNN Layer 2
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#CNN Layer 3
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#Global Average Pooling layer is used instead of Flatten as it is more effiecient
model.add(GlobalAveragePooling2D())

#Dense Layer 1
model.add(Dense(512))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

#Dense Layer 2
model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

#Output Layer
model.add(Dense(7, activation='softmax'))

#Adam Optimizer
opt = k.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\RAVI RAJ\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 639,239 (2.44 MB)
#  Trainable params: 636,807 (2.43 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %%
#Implementing Early Stopping and Learning Rate Reduction
es=EarlyStopping(monitor='val_loss', patience=25, verbose=1, restore_best_weights=True)
lr=ReduceLROnPlateau(monitor='val_loss', factor=0.001, patience=10, verbose=1, min_delta=0.0001)

callbacks_list=[es,lr]

# %%
history = model.fit(
    traingen,
    epochs=100,
    validation_data=testgen,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/100
# C:\Users\RAVI RAJ\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 40s 111ms/step - accuracy: 0.2359 - loss: 2.4917 - val_accuracy: 0.3862 - val_loss: 1.9626 - learning_rate: 0.0010
# Epoch 2/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.3391 - loss: 1.8424 - val_accuracy: 0.3745 - val_loss: 1.8587 - learning_rate: 0.0010
# Epoch 3/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 75ms/step - accuracy: 0.3684 - loss: 1.6822 - val_accuracy: 0.3820 - val_loss: 1.6173 - learning_rate: 0.0010
# Epoch 4/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.4007 - loss: 1.6202 - val_accuracy: 0.3719 - val_loss: 1.6232 - learning_rate: 0.0010
# Epoch 5/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.4326 - loss: 1.5378 - val_accuracy: 0.3168 - val_loss: 1.7446 - learning_rate: 0.0010
# Epoch 6/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.4582 - loss: 1.4929 - val_accuracy: 0.2595 - val_loss: 2.4297 - learning_rate: 0.0010
# Epoch 7/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.4770 - loss: 1.4558 - val_accuracy: 0.4583 - val_loss: 1.4976 - learning_rate: 0.0010
# Epoch 8/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.4896 - loss: 1.3833 - val_accuracy: 0.4325 - val_loss: 1.5669 - learning_rate: 0.0010
# Epoch 9/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.5004 - loss: 1.3505 - val_accuracy: 0.4241 - val_loss: 1.5648 - learning_rate: 0.0010
# Epoch 10/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.5247 - loss: 1.3051 - val_accuracy: 0.4980 - val_loss: 1.5016 - learning_rate: 0.0010
# Epoch 11/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.5508 - loss: 1.2350 - val_accuracy: 0.3729 - val_loss: 1.7346 - learning_rate: 0.0010
# Epoch 12/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.5593 - loss: 1.2120 - val_accuracy: 0.5228 - val_loss: 1.2659 - learning_rate: 0.0010
# Epoch 13/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.5740 - loss: 1.1678 - val_accuracy: 0.5561 - val_loss: 1.1829 - learning_rate: 0.0010
# Epoch 14/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.5831 - loss: 1.1506 - val_accuracy: 0.6314 - val_loss: 1.0185 - learning_rate: 0.0010
# Epoch 15/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.5959 - loss: 1.1290 - val_accuracy: 0.6125 - val_loss: 1.0679 - learning_rate: 0.0010
# Epoch 16/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.5971 - loss: 1.1043 - val_accuracy: 0.5984 - val_loss: 1.0582 - learning_rate: 0.0010
# Epoch 17/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.5914 - loss: 1.1249 - val_accuracy: 0.5212 - val_loss: 1.2482 - learning_rate: 0.0010
# Epoch 18/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6094 - loss: 1.0696 - val_accuracy: 0.6330 - val_loss: 1.0111 - learning_rate: 0.0010
# Epoch 19/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6138 - loss: 1.0694 - val_accuracy: 0.6463 - val_loss: 0.9735 - learning_rate: 0.0010
# Epoch 20/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6260 - loss: 1.0324 - val_accuracy: 0.6816 - val_loss: 0.8863 - learning_rate: 0.0010
# Epoch 21/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6148 - loss: 1.0476 - val_accuracy: 0.5192 - val_loss: 1.3174 - learning_rate: 0.0010
# Epoch 22/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6318 - loss: 1.0297 - val_accuracy: 0.6747 - val_loss: 0.8815 - learning_rate: 0.0010
# Epoch 23/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6195 - loss: 1.0516 - val_accuracy: 0.6770 - val_loss: 0.8790 - learning_rate: 0.0010
# Epoch 24/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6313 - loss: 1.0051 - val_accuracy: 0.6532 - val_loss: 0.9417 - learning_rate: 0.0010
# Epoch 25/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6547 - loss: 0.9695 - val_accuracy: 0.6897 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 26/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6431 - loss: 0.9932 - val_accuracy: 0.5988 - val_loss: 1.0749 - learning_rate: 0.0010
# Epoch 27/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6560 - loss: 0.9607 - val_accuracy: 0.6604 - val_loss: 0.9410 - learning_rate: 0.0010
# Epoch 28/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6482 - loss: 0.9640 - val_accuracy: 0.5460 - val_loss: 1.1775 - learning_rate: 0.0010
# Epoch 29/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6473 - loss: 0.9832 - val_accuracy: 0.6470 - val_loss: 0.9697 - learning_rate: 0.0010
# Epoch 30/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6463 - loss: 0.9758 - val_accuracy: 0.6177 - val_loss: 1.0241 - learning_rate: 0.0010
# Epoch 31/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6562 - loss: 0.9476 - val_accuracy: 0.6767 - val_loss: 0.8972 - learning_rate: 0.0010
# Epoch 32/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6683 - loss: 0.9246 - val_accuracy: 0.5287 - val_loss: 1.2715 - learning_rate: 0.0010
# Epoch 33/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6543 - loss: 0.9512 - val_accuracy: 0.6072 - val_loss: 1.0383 - learning_rate: 0.0010
# Epoch 34/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6670 - loss: 0.9272 - val_accuracy: 0.7034 - val_loss: 0.8219 - learning_rate: 0.0010
# Epoch 35/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6686 - loss: 0.9232 - val_accuracy: 0.7239 - val_loss: 0.7717 - learning_rate: 0.0010
# Epoch 36/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 459s 1s/step - accuracy: 0.6585 - loss: 0.9392 - val_accuracy: 0.6555 - val_loss: 0.9641 - learning_rate: 0.0010
# Epoch 37/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - accuracy: 0.6621 - loss: 0.9389 - val_accuracy: 0.7053 - val_loss: 0.7976 - learning_rate: 0.0010
# Epoch 38/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.6718 - loss: 0.9216 - val_accuracy: 0.6721 - val_loss: 0.8834 - learning_rate: 0.0010
# Epoch 39/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6647 - loss: 0.9238 - val_accuracy: 0.7203 - val_loss: 0.7903 - learning_rate: 0.0010
# Epoch 40/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6829 - loss: 0.8866 - val_accuracy: 0.7141 - val_loss: 0.8045 - learning_rate: 0.0010
# Epoch 41/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6843 - loss: 0.8885 - val_accuracy: 0.7086 - val_loss: 0.8259 - learning_rate: 0.0010
# Epoch 42/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6704 - loss: 0.9094 - val_accuracy: 0.7161 - val_loss: 0.7953 - learning_rate: 0.0010
# Epoch 43/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6838 - loss: 0.8955 - val_accuracy: 0.7334 - val_loss: 0.7619 - learning_rate: 0.0010
# Epoch 44/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6822 - loss: 0.8910 - val_accuracy: 0.7210 - val_loss: 0.7922 - learning_rate: 0.0010
# Epoch 45/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6818 - loss: 0.8852 - val_accuracy: 0.6718 - val_loss: 0.8986 - learning_rate: 0.0010
# Epoch 46/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6801 - loss: 0.8895 - val_accuracy: 0.7383 - val_loss: 0.7162 - learning_rate: 0.0010
# Epoch 47/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 29s 84ms/step - accuracy: 0.6884 - loss: 0.8672 - val_accuracy: 0.7334 - val_loss: 0.7679 - learning_rate: 0.0010
# Epoch 48/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6903 - loss: 0.8753 - val_accuracy: 0.5743 - val_loss: 1.1745 - learning_rate: 0.0010
# Epoch 49/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.6856 - loss: 0.8736 - val_accuracy: 0.7282 - val_loss: 0.7656 - learning_rate: 0.0010
# Epoch 50/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6790 - loss: 0.8814 - val_accuracy: 0.7122 - val_loss: 0.8047 - learning_rate: 0.0010
# Epoch 51/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6978 - loss: 0.8412 - val_accuracy: 0.7210 - val_loss: 0.8081 - learning_rate: 0.0010
# Epoch 52/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 75ms/step - accuracy: 0.6937 - loss: 0.8569 - val_accuracy: 0.6832 - val_loss: 0.8427 - learning_rate: 0.0010
# Epoch 53/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6962 - loss: 0.8398 - val_accuracy: 0.7376 - val_loss: 0.7506 - learning_rate: 0.0010
# Epoch 54/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6946 - loss: 0.8448 - val_accuracy: 0.6591 - val_loss: 0.9071 - learning_rate: 0.0010
# Epoch 55/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.6858 - loss: 0.8671 - val_accuracy: 0.7005 - val_loss: 0.8002 - learning_rate: 0.0010
# Epoch 56/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6883 - loss: 0.8453
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6884 - loss: 0.8453 - val_accuracy: 0.7014 - val_loss: 0.8464 - learning_rate: 0.0010
# Epoch 57/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7019 - loss: 0.8233 - val_accuracy: 0.7516 - val_loss: 0.7075 - learning_rate: 1.0000e-06
# Epoch 58/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7029 - loss: 0.8311 - val_accuracy: 0.7549 - val_loss: 0.7055 - learning_rate: 1.0000e-06
# Epoch 59/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 77ms/step - accuracy: 0.7030 - loss: 0.8180 - val_accuracy: 0.7542 - val_loss: 0.7038 - learning_rate: 1.0000e-06
# Epoch 60/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7032 - loss: 0.8397 - val_accuracy: 0.7542 - val_loss: 0.7046 - learning_rate: 1.0000e-06
# Epoch 61/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.7031 - loss: 0.8188 - val_accuracy: 0.7555 - val_loss: 0.7023 - learning_rate: 1.0000e-06
# Epoch 62/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.7037 - loss: 0.8217 - val_accuracy: 0.7552 - val_loss: 0.7053 - learning_rate: 1.0000e-06
# Epoch 63/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7072 - loss: 0.8129 - val_accuracy: 0.7555 - val_loss: 0.7016 - learning_rate: 1.0000e-06
# Epoch 64/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.7045 - loss: 0.8228 - val_accuracy: 0.7542 - val_loss: 0.7045 - learning_rate: 1.0000e-06
# Epoch 65/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7107 - loss: 0.8238 - val_accuracy: 0.7565 - val_loss: 0.7033 - learning_rate: 1.0000e-06
# Epoch 66/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6957 - loss: 0.8485 - val_accuracy: 0.7555 - val_loss: 0.7031 - learning_rate: 1.0000e-06
# Epoch 67/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.7000 - loss: 0.8271 - val_accuracy: 0.7536 - val_loss: 0.7038 - learning_rate: 1.0000e-06
# Epoch 68/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6975 - loss: 0.8262 - val_accuracy: 0.7542 - val_loss: 0.7027 - learning_rate: 1.0000e-06
# Epoch 69/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.6978 - loss: 0.8346 - val_accuracy: 0.7542 - val_loss: 0.7062 - learning_rate: 1.0000e-06
# Epoch 70/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.6959 - loss: 0.8254 - val_accuracy: 0.7549 - val_loss: 0.7008 - learning_rate: 1.0000e-06
# Epoch 71/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7056 - loss: 0.8349 - val_accuracy: 0.7555 - val_loss: 0.7021 - learning_rate: 1.0000e-06
# Epoch 72/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7023 - loss: 0.8250 - val_accuracy: 0.7549 - val_loss: 0.7006 - learning_rate: 1.0000e-06
# Epoch 73/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.7101 - loss: 0.8154 - val_accuracy: 0.7549 - val_loss: 0.7006 - learning_rate: 1.0000e-06
# Epoch 74/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6997 - loss: 0.8243 - val_accuracy: 0.7546 - val_loss: 0.7016 - learning_rate: 1.0000e-06
# Epoch 75/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6965 - loss: 0.8334 - val_accuracy: 0.7536 - val_loss: 0.7000 - learning_rate: 1.0000e-06
# Epoch 76/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 26s 76ms/step - accuracy: 0.7068 - loss: 0.8276 - val_accuracy: 0.7539 - val_loss: 0.7002 - learning_rate: 1.0000e-06
# Epoch 77/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.7005 - loss: 0.8335 - val_accuracy: 0.7536 - val_loss: 0.7031 - learning_rate: 1.0000e-06
# Epoch 78/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.7120 - loss: 0.8052 - val_accuracy: 0.7555 - val_loss: 0.7037 - learning_rate: 1.0000e-06
# Epoch 79/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 18980s 55s/step - accuracy: 0.7012 - loss: 0.8079 - val_accuracy: 0.7546 - val_loss: 0.7005 - learning_rate: 1.0000e-06
# Epoch 80/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 31s 89ms/step - accuracy: 0.7062 - loss: 0.8207 - val_accuracy: 0.7536 - val_loss: 0.7050 - learning_rate: 1.0000e-06
# Epoch 81/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 29s 84ms/step - accuracy: 0.7127 - loss: 0.8051 - val_accuracy: 0.7559 - val_loss: 0.7012 - learning_rate: 1.0000e-06
# Epoch 82/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7000 - loss: 0.8212 - val_accuracy: 0.7533 - val_loss: 0.7028 - learning_rate: 1.0000e-06
# Epoch 83/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7108 - loss: 0.8086 - val_accuracy: 0.7555 - val_loss: 0.6985 - learning_rate: 1.0000e-06
# Epoch 84/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.6958 - loss: 0.8341 - val_accuracy: 0.7539 - val_loss: 0.7033 - learning_rate: 1.0000e-06
# Epoch 85/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.7040 - loss: 0.8262 - val_accuracy: 0.7520 - val_loss: 0.7024 - learning_rate: 1.0000e-06
# Epoch 86/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.7000 - loss: 0.8256 - val_accuracy: 0.7526 - val_loss: 0.7033 - learning_rate: 1.0000e-06
# Epoch 87/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.7068 - loss: 0.8086 - val_accuracy: 0.7536 - val_loss: 0.7029 - learning_rate: 1.0000e-06
# Epoch 88/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6962 - loss: 0.8251 - val_accuracy: 0.7516 - val_loss: 0.7045 - learning_rate: 1.0000e-06
# Epoch 89/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.7085 - loss: 0.8134 - val_accuracy: 0.7542 - val_loss: 0.7003 - learning_rate: 1.0000e-06
# Epoch 90/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 30s 86ms/step - accuracy: 0.7117 - loss: 0.8174 - val_accuracy: 0.7516 - val_loss: 0.7037 - learning_rate: 1.0000e-06
# Epoch 91/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - accuracy: 0.7067 - loss: 0.8037 - val_accuracy: 0.7507 - val_loss: 0.7045 - learning_rate: 1.0000e-06
# Epoch 92/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 30s 87ms/step - accuracy: 0.7037 - loss: 0.8128 - val_accuracy: 0.7539 - val_loss: 0.7018 - learning_rate: 1.0000e-06
# Epoch 93/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6979 - loss: 0.8383
# Epoch 93: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-10.
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.6980 - loss: 0.8383 - val_accuracy: 0.7526 - val_loss: 0.7020 - learning_rate: 1.0000e-06
# Epoch 94/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7051 - loss: 0.8101 - val_accuracy: 0.7552 - val_loss: 0.6982 - learning_rate: 1.0000e-09
# Epoch 95/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.7127 - loss: 0.8034 - val_accuracy: 0.7529 - val_loss: 0.7006 - learning_rate: 1.0000e-09
# Epoch 96/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7057 - loss: 0.8233 - val_accuracy: 0.7526 - val_loss: 0.7038 - learning_rate: 1.0000e-09
# Epoch 97/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7173 - loss: 0.7846 - val_accuracy: 0.7523 - val_loss: 0.7017 - learning_rate: 1.0000e-09
# Epoch 98/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7003 - loss: 0.8122 - val_accuracy: 0.7526 - val_loss: 0.7034 - learning_rate: 1.0000e-09
# Epoch 99/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 78ms/step - accuracy: 0.7100 - loss: 0.8075 - val_accuracy: 0.7533 - val_loss: 0.7011 - learning_rate: 1.0000e-09
# Epoch 100/100
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 27s 79ms/step - accuracy: 0.7081 - loss: 0.8059 - val_accuracy: 0.7526 - val_loss: 0.7024 - learning_rate: 1.0000e-09
# Restoring model weights from the end of the best epoch: 94.

# %%
#Predicting
test_loss, test_accuracy = model.evaluate(testgen)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6999 - loss: 0.8720

# %%
print(f"Test Accuracy: {test_accuracy:.2f}")
y_pred = np.argmax(model.predict(testgen), axis=1)
y_true = testgen.classes
print("Classification Report:")
print(classification_report(y_true, y_pred))
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix,'\n\n')
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds', 
            xticklabels=list(label_map.values()), 
            yticklabels=list(label_map.values()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
print("Training class indices:", traingen.class_indices)
print("Test class indices:", testgen.class_indices)
# Out:
# Test Accuracy: 0.76
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.67      0.75       329
#            1       0.62      0.50      0.55        74
#            2       0.47      0.17      0.25       160
#            3       0.92      0.86      0.89      1185
#            4       0.64      0.74      0.69       478
#            5       0.63      0.67      0.65       162
#            6       0.65      0.80      0.72       680
#
#     accuracy                           0.76      3068
#    macro avg       0.68      0.63      0.64      3068
# weighted avg       0.76      0.76      0.75      3068
#
# Confusion Matrix:
# [[ 221    7    4   15   21    8   53]
#  [   9   37    2    5    8    6    7]
#  [   6    1   28   17   31   20   57]
#  [  10    6    4 1019   41   14   91]
#  [   4    2    8   26  356   11   71]
#  [   3    6    3   11   14  109   16]
#  [  11    1   11   19   85    6  547]]
# Training class indices: {'1': 0, '2': 1, '3': 2, '4': 3, '5': 4, '6': 5, '7': 6}
# Test class indices: {'1': 0, '2': 1, '3': 2, '4': 3, '5': 4, '6': 5, '7': 6}

# %%
plt.figure(figsize=(12, 6))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='red')
plt.plot(history.history['val_loss'], label='Test Loss', color='green')
plt.title('Training and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='red')
plt.plot(history.history['val_accuracy'], label='Test Accuracy', color='green')
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Convert true labels to one-hot encoding for ROC calculations
y_true_onehot = label_binarize(y_true, classes=[0, 1, 2, 3, 4,5,6])
y_pred_prob = model.predict(testgen)

plt.figure(figsize=(10, 7))

# Plot ROC for each class
for i, class_name in label_map.items():
    fpr, tpr, _ = roc_curve(y_true_onehot[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
